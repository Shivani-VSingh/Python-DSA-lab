# %%
j1 = [24, 15, 17, 12.5, 'cat', True]
j1
# Out:
# [24, 15, 17, 12.5, 'cat', True]

# %%
salary=[20000,25000,36000,20000,45000,50000]

# %%
salary
# Out:
# [20000, 25000, 36000, 20000, 45000, 50000]

# %%
average= sum(salary)/len(salary)

# %%
average
# Out:
# 32666.666666666668

# %%
for s in salary:
    if s > average:
        print

# %%
def f1(x,y):
    return 3*x**3 + 2*y**2 + 1

# %%
f1(2,3)
# Out:
# 43
